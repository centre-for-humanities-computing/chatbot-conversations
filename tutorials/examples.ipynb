# %%
# !pip install chatting_chatbots
# Out:
# Requirement already satisfied: chatting_chatbots in /work/converAItions/.venv/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: datasets==1.14.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.14.0)
# Requirement already satisfied: numpy==1.21.2 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.21.2)
# Requirement already satisfied: pandas==1.3.4 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.3.4)
# Requirement already satisfied: pytorch-ignite==0.4.8 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (0.4.8)
# Requirement already satisfied: scikit-learn==1.0.2 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.0.2)
# Requirement already satisfied: scipy==1.7.3 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.7.3)
# Requirement already satisfied: torch==1.9.1 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (1.9.1)
# Requirement already satisfied: transformers==4.12.2 in /work/converAItions/.venv/lib/python3.7/site-packages (from chatting_chatbots) (4.12.2)
# Requirement already satisfied: dill in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (2.26.0)
# Requirement already satisfied: xxhash in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (2.0.2)
# Requirement already satisfied: huggingface-hub<0.1.0,>=0.0.19 in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (0.0.19)
# Requirement already satisfied: tqdm>=4.62.1 in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (4.62.3)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (5.0.0)
# Requirement already satisfied: packaging in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (21.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (2021.10.1)
# Requirement already satisfied: importlib-metadata in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (4.8.1)
# Requirement already satisfied: aiohttp in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (3.7.4.post0)
# Requirement already satisfied: multiprocess in /work/converAItions/.venv/lib/python3.7/site-packages (from datasets==1.14.0->chatting_chatbots) (0.70.12.2)
# Requirement already satisfied: pytz>=2017.3 in /work/converAItions/.venv/lib/python3.7/site-packages (from pandas==1.3.4->chatting_chatbots) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /work/converAItions/.venv/lib/python3.7/site-packages (from pandas==1.3.4->chatting_chatbots) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /work/converAItions/.venv/lib/python3.7/site-packages (from scikit-learn==1.0.2->chatting_chatbots) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from scikit-learn==1.0.2->chatting_chatbots) (3.1.0)
# Requirement already satisfied: typing-extensions in /work/converAItions/.venv/lib/python3.7/site-packages (from torch==1.9.1->chatting_chatbots) (3.10.0.2)
# Requirement already satisfied: sacremoses in /work/converAItions/.venv/lib/python3.7/site-packages (from transformers==4.12.2->chatting_chatbots) (0.0.45)
# Requirement already satisfied: pyyaml>=5.1 in /work/converAItions/.venv/lib/python3.7/site-packages (from transformers==4.12.2->chatting_chatbots) (5.4.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /work/converAItions/.venv/lib/python3.7/site-packages (from transformers==4.12.2->chatting_chatbots) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /work/converAItions/.venv/lib/python3.7/site-packages (from transformers==4.12.2->chatting_chatbots) (2021.8.28)
# Requirement already satisfied: filelock in /work/converAItions/.venv/lib/python3.7/site-packages (from transformers==4.12.2->chatting_chatbots) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /work/converAItions/.venv/lib/python3.7/site-packages (from packaging->datasets==1.14.0->chatting_chatbots) (2.4.7)
# Requirement already satisfied: six>=1.5 in /work/converAItions/.venv/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.3.4->chatting_chatbots) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /work/converAItions/.venv/lib/python3.7/site-packages (from requests>=2.19.0->datasets==1.14.0->chatting_chatbots) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /work/converAItions/.venv/lib/python3.7/site-packages (from requests>=2.19.0->datasets==1.14.0->chatting_chatbots) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /work/converAItions/.venv/lib/python3.7/site-packages (from requests>=2.19.0->datasets==1.14.0->chatting_chatbots) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from requests>=2.19.0->datasets==1.14.0->chatting_chatbots) (2.0.6)
# Requirement already satisfied: chardet<5.0,>=2.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from aiohttp->datasets==1.14.0->chatting_chatbots) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /work/converAItions/.venv/lib/python3.7/site-packages (from aiohttp->datasets==1.14.0->chatting_chatbots) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from aiohttp->datasets==1.14.0->chatting_chatbots) (1.7.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from aiohttp->datasets==1.14.0->chatting_chatbots) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /work/converAItions/.venv/lib/python3.7/site-packages (from aiohttp->datasets==1.14.0->chatting_chatbots) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /work/converAItions/.venv/lib/python3.7/site-packages (from importlib-metadata->datasets==1.14.0->chatting_chatbots) (3.5.0)
# Requirement already satisfied: click in /work/converAItions/.venv/lib/python3.7/site-packages (from sacremoses->transformers==4.12.2->chatting_chatbots) (8.0.1)

# %% [markdown]
# ##Example of creating and running an experiment

# %%
from chatting_chatbots import Experiment

experiment = Experiment(
    population={
        "John": "gpt2",
        "Margaret": "distilgpt2"
    },
    cycles=2,
    initial_context="Hi. Why are you late?",
    conversation_length=10,
    verbose=True,
    use_gpu=-1,
    use_files=False,
    batch_size=64
)

experiment.run()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_3709/2397190671.py in <module>
#      12     use_gpu=-1,
#      13     use_files=False,
# ---> 14     batch_size=64
#      15 )
#      16
#
# /work/converAItions/.venv/lib/python3.7/site-packages/chatting_chatbots/chatbots.py in __init__(self, population, cycles, initial_context, conversation_length, random_length, training_args, verbose, use_files, use_gpu, generation_parameters, context_size, full_conversation, batch_size, train_after_run, output_path, cache_path)
#      89             if isinstance(self.population[participant], str):
#      90                 tokenizer = AutoTokenizer.from_pretrained(
# ---> 91                     self.population[participant], cache_dir=cache_path
#      92                 )
#      93                 # add the EOS token as PAD token to avoid warnings
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     468         if config_tokenizer_class is None:
#     469             if not isinstance(config, PretrainedConfig):
# --> 470                 config = AutoConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     471             config_tokenizer_class = config.tokenizer_class
#     472
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     556         """
#     557         kwargs["_from_auto"] = True
# --> 558         config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     559         if "model_type" in config_dict:
#     560             config_class = CONFIG_MAPPING[config_dict["model_type"]]
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     556                 local_files_only=local_files_only,
#     557                 use_auth_token=use_auth_token,
# --> 558                 user_agent=user_agent,
#     559             )
#     560             # Load config dict
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1497             user_agent=user_agent,
#    1498             use_auth_token=use_auth_token,
# -> 1499             local_files_only=local_files_only,
#    1500         )
#    1501     elif os.path.exists(url_or_filename):
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1753             logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
#    1754
# -> 1755             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1756
#    1757         logger.info(f"storing {url} in cache at {cache_path}")
#
# /work/converAItions/.venv/lib/python3.7/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1610         initial=resume_size,
#    1611         desc="Downloading",
# -> 1612         disable=bool(logging.get_verbosity() == logging.NOTSET),
#    1613     )
#    1614     for chunk in r.iter_content(chunk_size=1024):
#
# /work/converAItions/.venv/lib/python3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# /work/converAItions/.venv/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     114         if IProgress is None:  # #187 #451 #558 #872
#     115             raise ImportError(
# --> 116                 "IProgress not found. Please update jupyter and ipywidgets."
#     117                 " See https://ipywidgets.readthedocs.io/en/stable"
#     118                 "/user_install.html")
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ##Example of training one of the models for 5 epochs

# %%
from transformers import TrainingArguments
arguments = TrainingArguments(
    output_dir="training",
    per_device_train_batch_size=4,
    evaluation_strategy="steps",
    logging_steps=500,
    num_train_epochs=5,
    weight_decay=0.01
)

experiment.train_participant("John", arguments)
